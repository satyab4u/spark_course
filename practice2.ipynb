# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession\
        .builder\
        .appName("PythonWordCount")\
        .getOrCreate()

# %%
lines  = spark.read.text("/Users/Satya/Documents/SparkCourse/book.txt").rdd.map(lambda r: r[0])

# %%
import re
def normalizeWords(text):
    return re.compile(r'\W+',re.UNICODE).
words = lines.flatMap(lambda x: x.split(' '))

# %%
wordCounts = words.map(lambda x: (x, 1)).reduceByKey(lambda x, y: x+y)

# %%
wordCountsSorted = wordCounts.map(lambda x, y: (y,x)).sortByKey()

# %%
wordCounts
# Out:
# PythonRDD[51] at RDD at PythonRDD.scala:53

# %%
print(wordCountsSorted.collect())
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-42-8b4b74500e27> in <module>
# ----> 1 print(wordCountsSorted.collect())
#
# /usr/local/Cellar/apache-spark/2.4.5/libexec/python/pyspark/rdd.py in collect(self)
#     814         """
#     815         with SCCallSiteSync(self.context) as css:
# --> 816             sock_info = self.ctx._jvm.PythonRDD.collectAndServe(self._jrdd.rdd())
#     817         return list(_load_from_socket(sock_info, self._jrdd_deserializer))
#     818
#
# /usr/local/Cellar/apache-spark/2.4.5/libexec/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1255         answer = self.gateway_client.send_command(command)
#    1256         return_value = get_return_value(
# -> 1257             answer, self.gateway_client, self.target_id, self.name)
#    1258
#    1259         for temp_arg in temp_args:
#
# ...
